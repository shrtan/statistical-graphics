# %%
import pandas as pd
import numpy as np

hosp = pd.read_csv('hosp.csv')

hosp.shape
hosp.head()
# Out:
#   Data_Month_Date       Country HB_Treatment_Description  \
# 0          Jul-07  NHS Scotland     NHS Ayrshire & Arran
# 1          Jul-07  NHS Scotland     NHS Ayrshire & Arran
# 2          Jul-07  NHS Scotland     NHS Ayrshire & Arran
# 3          Jul-07  NHS Scotland     NHS Ayrshire & Arran
# 4          Jul-07  NHS Scotland              NHS Borders
#
#   Treatment_Location_Code              Treatment_Location_Name     ED_MIU  \
# 0                   A101H          Arran War Memorial Hospital  MIU/Other
# 1                   A111H  University Hospital Crosshouse - ED         ED
# 2                   A207H            Davidson Cottage Hospital  MIU/Other
# 3                   A210H         University Hospital Ayr - ED         ED
# 4                   B103H             Knoll Community Hospital  MIU/Other
#
#    Number_Of_Attendances_agg  Number_of_Attendances_Epi  \
# 0                        252                        NaN
# 1                       5414                     5414.0
# ...

# %%
hosp["Year"] = [x[-2:] for x in hosp["Data_Month_Date"]]
hosp["HB_Treatment_Description"]
hosp["Data_Month_Date"]
hosp["Year"]
# Out:
# 0        07
# 1        07
# 2        07
# 3        07
# 4        07
#          ..
# 15466    21
# 15467    21
# 15468    21
# 15469    21
# 15470    21
# Name: Year, Length: 15471, dtype: object
